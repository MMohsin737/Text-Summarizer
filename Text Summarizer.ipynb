# %%
import os
import sys
import math
import pandas as pd
import nltk as nl
import numpy as np
import json
import gensim.models.keyedvectors as word2vec
import re
import skfuzzy as fuzz
from jgtextrank import keywords_extraction

import pyswarms as ps
from pyswarms.utils.functions import single_obj as fx

# %%
# from nltk.stem.porter import *
from functools import singledispatch
from nltk.stem.snowball import SnowballStemmer
from nltk.corpus import stopwords
from string import punctuation

from collections import Counter

from sklearn.metrics.pairwise import cosine_similarity

from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering

from pyeasyga import pyeasyga
# from geneticalgorithm import geneticalgorithm as ga

from lexrank import STOPWORDS, LexRank
# Out:
# 2021-04-26 22:17:32,050 - filelock - INFO - Lock 1714673706224 acquired on C:\ProgramData\Anaconda3\lib\site-packages\urlextract\data\tlds-alpha-by-domain.txt.lock
# 2021-04-26 22:17:32,078 - filelock - INFO - Lock 1714673706224 released on C:\ProgramData\Anaconda3\lib\site-packages\urlextract\data\tlds-alpha-by-domain.txt.lock

# %%
# from pprint import pprint
from fuzzy_logic.terms import Term
from fuzzy_logic.variables import FuzzyVariable
from fuzzy_logic.mamdani_fs import MamdaniFuzzySystem
from fuzzy_logic.mf import TriangularMF

# %%
@singledispatch
def to_serializable(val):
    """Used by default."""
    return str(val)

@to_serializable.register(np.float32)
def ts_float32(val):
    """Used if *val* is an instance of numpy.float32."""
    return np.float64(val)

# %% [markdown]
# # Text Pre-Processing

# %%
# stemmer = PorterStemmer()
stemmer = SnowballStemmer(language='english')

# %%
def remove_stop_words(words):
    """
    Will remove stop words from a list
    :param words: input list
    :return: output list of words without stop words.
    """
    custom_stop_words = set(stopwords.words('english') + list(punctuation))
    return [stemmer.stem(word) for word in words if word not in custom_stop_words]

# %%
def tokenize(text, stop_words):
    """
    Tokenizes a given text and also removes stop words.
    :param text:
    :param stop_words:
    :return:
    """
    words = nl.word_tokenize(text)
    words = [w.lower() for w in words]
    return [w for w in words if w not in stop_words and not w.isdigit()]

# %%
def text_cleaner(in_text):
    """

    :param in_text:
    :return:
    """
    cleaned_text = re.sub(r'([a-zA-Z])\\1{2,}', r'$1', in_text)
    cleaned_text = re.sub("\S*\d\S*", "", cleaned_text).strip()
    return re.sub(r'[^a-zA-Z0-9\s,.]', '', cleaned_text)

# %%
def get_cleaned_text(text):
    """

    :param text:
    :return:
    """

    in_text = text.lower()
    cleaned_text = text_cleaner(in_text)
    tokens = nl.word_tokenize(cleaned_text)

    # TODO : Use setemimng here.
    return remove_stop_words(tokens)

# %% [markdown]
# # Util Functions

# %%
def get_sen_length(sen):
    return len(nl.word_tokenize(sen))

# %%
# def get_sen_pos(postion, total_sens):
#     postion = 1 if postion == 0 else postion
#     return (postion - 1) / total_sens

def get_sen_pos(postion, total_sens):
    postion += 1
    postion = 1 if postion == total_sens else postion
    postion = 2 if postion == (total_sens - 1) else postion
    return (total_sens - postion) / total_sens

# %%
def get_proper_nouns(sentence):
    nnp = [word for word, pos in nl.pos_tag(nl.word_tokenize(str(sentence))) if pos == 'NNP']
    return len(nnp)

# %%
def extract_np(psent):
    for subtree in psent.subtrees():
        if subtree.label() == 'NP':
            yield ' '.join(word for word, tag in subtree.leaves())

# %%
def get_np_vps(sen):
    # Todo check grammar for verb phrases
    grammar = r"""
          NP: {<DT|PP\$>?<JJ>*<NN>}   # chunk determiner/possessive, adjectives and noun
          {<NNP>+}                # chunk sequences of proper nouns
          {<NN>+}                 # chunk consecutive nouns
          VP: {<VB.*><NP|PP|CLAUSE>+$}
          """
    cp = nl.RegexpParser(grammar)

    tagged_sent = nl.pos_tag(sen.split())
    parsed_sent = cp.parse(tagged_sent)
    nps = []
    for npstr in extract_np(parsed_sent):
        nps.append(npstr)
    return nps

# %%
def vectorize_sent(sent, model):
    # print(pre_process(sent))
    return np.mean([model[w] for w in get_cleaned_text(sent) if w in model]
                   or [np.zeros(300)], axis=0)

# %%
def get_sen_vec_list(sens, model):
    index_vec_list = []
    for i, sen in enumerate(sens):
        vec = vectorize_sent(sen, model)
        index_vec_list.append(vec)
    return index_vec_list

# %%
def calculate_tf_idf_sum(sen, D, df_map):
    tokens = get_cleaned_text(sen)
    tf_map = dict(Counter(tokens))
    tf_idf_map = {k: (v * math.log(D / df_map.get(k, 1))) for k, v in tf_map.items()}
    return sum(tf_idf_map.values())

# %%
def get_sen_cohesiveness(sens, model):
    index_vec_list = get_sen_vec_list(sens, model)
    sen_score_map = {}
    # print(index_vec_list)
    c_s_array = (cosine_similarity(index_vec_list, index_vec_list))
    cohesiveness = (c_s_array.sum(axis=0)) - 1
    return {i: v for i, v in enumerate(cohesiveness)}

# %%
def get_sentences(text):
    return nl.sent_tokenize(text)

# %%
def get_val(val, min_val, max_val):
    min_val = 1 if min_val <= 0 else min_val
    return (val - min_val) / (max_val - min_val)

# %%
def load_model(model_path):
    return word2vec.KeyedVectors.load_word2vec_format(model_path, binary=True)

# %% [markdown]
# # Base Summrizer

# %%
# nltk.download('reuters')
from nltk.corpus import reuters, stopwords

# %%
def normalize_values(res_arr):
    # print([x['tf_idf'] for x in res_arr])
    min_max_map = {}
    for k in ['tf_idf', 'sen_length', 'proper_nouns', 'np_vps', 'c_score', 'sen_pos']:
        min_max_map.setdefault(k, {})['max'] = max([x[k] for x in res_arr])
        min_max_map[k]['min'] = min([x[k] for x in res_arr])
    result = []
    # print(min_max_map)
    for r in res_arr:
        tf_idf = get_val(r['tf_idf'], min_max_map['tf_idf']['min'], min_max_map['tf_idf']['max'])
        sen_length = get_val(r['sen_length'], min_max_map['sen_length']['min'], min_max_map['sen_length']['max'])
        proper_nouns = get_val(r['proper_nouns'], min_max_map['proper_nouns']['min'],
                               min_max_map['proper_nouns']['max'])
        np_vps = get_val(r['np_vps'], min_max_map['np_vps']['min'], min_max_map['np_vps']['max'])
        c_score = get_val(r['c_score'], min_max_map['c_score']['min'], min_max_map['c_score']['max'])
        sen_pos = r['sen_pos']
        total_score = 0.7 * tf_idf + 0.05 * sen_length + 0.025 * proper_nouns + \
                      0.025 * np_vps + 0.15 * c_score + 0.15 * sen_pos
        obj = {'tf_idf': 0.7 * tf_idf, 'sen_length': 0.05 * sen_length, 'proper_nouns': 0.025 * proper_nouns,
               'np_vps': 0.025 * np_vps,
               'c_score': 0.15 * c_score, 'sen_pos': 0.15 * sen_pos, 'total_score': total_score, 'index': r['index']}
        result.append(obj)
    return result

# %%
def get_final_sen_ranks(text, D, df_map, model):
    curpath = os.path.abspath(os.curdir)
    sens = get_sentences(text)
    t = len(sens)
    coh_map = get_sen_cohesiveness(sens, model)
    result_array = []

    for i, s in enumerate(sens):
        # print(s)
        tf_idf = calculate_tf_idf_sum(s, D, df_map)
        sen_length = get_sen_length(s)
        proper_nouns = get_proper_nouns(s)
        np_vps = len(get_np_vps(s))
        c_score = coh_map[i]
        pos = get_sen_pos(i, t)
        rank_obj = {'tf_idf': tf_idf, 'sen_length': sen_length, 'proper_nouns': proper_nouns,
                    'np_vps': np_vps, 'c_score': c_score, 'sen_pos': pos, 'index': i}
        # print("   ", rank_obj)
        result_array.append(rank_obj)
    result = normalize_values(result_array)
    wr = open(os.path.join(curpath, '/tmp/score.json'), "w")
    for i, r in enumerate(result):
        r["sentence"] = sens[i]
        wr.write(json.dumps(r) + "\n")
    return result, sens

# %%
def return_postive_value(val):
    if(val < 0):
        val = -val
    return val

# %%
def fuzzy_model(res_array):
    min_max_map = {}    
    result = []
    
    t1 = Term('L', TriangularMF(0, 0.1, 0.2))
    t2 = Term('H', TriangularMF(0.2, 0.5, 1.0))

    tf_idf: FuzzyVariable = FuzzyVariable('tf_idf', 0.0, 1.0, t1, t2)
    sen_length: FuzzyVariable = FuzzyVariable('sen_length', 0.0, 1.0, t1, t2)
    proper_nouns: FuzzyVariable = FuzzyVariable('proper_nouns', 0.0, 1.0, t1, t2)
    np_vps: FuzzyVariable = FuzzyVariable('np_vps', 0.0, 1.0, t1, t2)
    c_score: FuzzyVariable = FuzzyVariable('c_score', 0.0, 1.0, t1, t2)
    sen_pos: FuzzyVariable = FuzzyVariable('sen_pos', 0.0, 1.0, t1, t2)
        
    output = FuzzyVariable(
        'output', 0.0, 1.0,
        Term('unimportant', TriangularMF(0.0, 0.1, 0.2)),
        Term('average', TriangularMF(0.2, 0.3, 0.4)),
        Term('good', TriangularMF(0.4, 0.5, 0.7)),
        Term('important', TriangularMF(0.7, 0.8, 1)),
    )
    
    mf: MamdaniFuzzySystem = MamdaniFuzzySystem([tf_idf, sen_length, proper_nouns, np_vps, c_score, sen_pos], [output])

    fuzzy_rules = pd.read_csv(r'C:\Users\Mohsin\Desktop\Desktop\Fuzzy Logics Rules (Thesis)\rules_v3.csv')
    for item in fuzzy_rules.values:
        mf.rules.append(mf.parse_rule("if (tf_idf is " + item [0] + ") and (sen_length is " + item [1] + ") and (proper_nouns is " + item [2] + ") and (np_vps is " + item [3] + ") and (c_score is " + item [4] + ") and (sen_pos is " + item [5] + ") then (output is " + item [6] + ")"))
        
        
    for k in ['tf_idf', 'sen_length', 'proper_nouns', 'np_vps', 'c_score', 'sen_pos']:
        min_max_map.setdefault(k, {})['max'] = max([x[k] for x in res_array])
        min_max_map[k]['min'] = min([x[k] for x in res_array])

        
    for r in res_array:
        
        tfIdf = get_val(r['tf_idf'], min_max_map['tf_idf']['min'], min_max_map['tf_idf']['max'])
        senLength = get_val(r['sen_length'], min_max_map['sen_length']['min'], min_max_map['sen_length']['max'])
        properNouns = get_val(r['proper_nouns'], min_max_map['proper_nouns']['min'], min_max_map['proper_nouns']['max']) 
        npVps = get_val(r['np_vps'], min_max_map['np_vps']['min'], min_max_map['np_vps']['max'])
        cScore = get_val(r['c_score'], min_max_map['c_score']['min'], min_max_map['c_score']['max']) 
        senPos = ((r['sen_pos'] - min_max_map['sen_pos']['min'])/(min_max_map['sen_pos']['max'] - min_max_map['sen_pos']['min']))
        
        resultant_value = mf.calculate({
            tf_idf: ts_float32(return_postive_value(tfIdf)), 
            sen_length: ts_float32(return_postive_value(senLength)), 
            proper_nouns: ts_float32(return_postive_value(properNouns)), 
            np_vps: ts_float32(return_postive_value(npVps)), 
            c_score: ts_float32(return_postive_value(cScore)), 
            sen_pos: ts_float32(return_postive_value(senPos))
        })
        
        fuzzy_score = [val for val in resultant_value.values()]
        
        print("fuzzay Score: ", fuzzy_score)
        
        obj = {
            'tf_idf': ts_float32(return_postive_value(tfIdf)),
            'sen_length': ts_float32(return_postive_value(senLength)),
            'proper_nouns': ts_float32(return_postive_value(properNouns)),
            'np_vps': ts_float32(return_postive_value(npVps)),
            'c_score': ts_float32(return_postive_value(cScore)),
            'sen_pos': ts_float32(return_postive_value(senPos)),
            'total_score': fuzzy_score[0],
            'index': r['index']
        }
        
        result.append(obj)
    
    return result

# %%
def fuzzy_ranking_model(text, D, df_map, model):
    curpath = os.path.abspath(os.curdir)
    sens = get_sentences(text)
    t = len(sens)
    coh_map = get_sen_cohesiveness(sens, model)
    result_array = []
    
    
    for i, s in enumerate(sens):
        # print(s)
        tf_idf = calculate_tf_idf_sum(s, D, df_map)
        sen_length = get_sen_length(s)
        proper_nouns = get_proper_nouns(s)
        np_vps = len(get_np_vps(s))
        c_score = coh_map[i]
        pos = get_sen_pos(i, t)
    
        rank_obj = {
            'tf_idf': tf_idf, 
            'sen_length': sen_length, 
            'proper_nouns': proper_nouns,
            'np_vps': np_vps,
            'c_score': c_score,
            'sen_pos': pos,
            'index': i
        }
        
        result_array.append(rank_obj)
        
        
    result = fuzzy_model(result_array)

    wr = open(os.path.join(curpath, '/tmp/score.json'), "w")
    for i, r in enumerate(result):
        r["sentence"] = sens[i]
        wr.write(json.dumps(r) + "\n")
    return result, sens

# %%
def fitness (individual, data):
    fitness = 0
    for (selected, (feature_label, score)) in zip(individual, data):
        if selected:
            fitness += score            
    return fitness

# def fitness (individual, data):
#     fitness = 0
#     if individual.count(1) == 3:
#         for (selected, (feature_label, score)) in zip(individual, data):
#             if selected:
#                 fitness += score    
#     return fitness

# %%
def ga_model(res_array):
    min_max_map = {}    
    result = [] 
#     senetnce_scores = []
        
    for k in ['tf_idf', 'sen_length', 'proper_nouns', 'np_vps', 'c_score', 'sen_pos']:
        min_max_map.setdefault(k, {})['max'] = max([x[k] for x in res_array])
        min_max_map[k]['min'] = min([x[k] for x in res_array])
    
        
    for r in res_array:
        
        tfIdf = get_val(r['tf_idf'], min_max_map['tf_idf']['min'], min_max_map['tf_idf']['max'])
        senLength = get_val(r['sen_length'], min_max_map['sen_length']['min'], min_max_map['sen_length']['max'])
        properNouns = get_val(r['proper_nouns'], min_max_map['proper_nouns']['min'], min_max_map['proper_nouns']['max']) 
        npVps = get_val(r['np_vps'], min_max_map['np_vps']['min'], min_max_map['np_vps']['max'])
        cScore = get_val(r['c_score'], min_max_map['c_score']['min'], min_max_map['c_score']['max']) 
        senPos = ((r['sen_pos'] - min_max_map['sen_pos']['min'])/(min_max_map['sen_pos']['max'] - min_max_map['sen_pos']['min']))
        
        data = [('tfidf', tfIdf), ('sen_length', senLength), ('proper_nouns', properNouns), ('np_vps', npVps), ('c_score', cScore), ('sen_pos', senPos)]
        
        ga = pyeasyga.GeneticAlgorithm(
            data,
            population_size = 100,
            generations = 100,
            crossover_probability = 0.8,
            mutation_probability = 0.2,
            elitism = True,
            maximise_fitness = True
        )
        
        ga.fitness_function = fitness
        
        ga.run()
        
        res = ga.best_individual()
        
        totalScore = res[0] * ts_float32(return_postive_value(tfIdf)) + res[0] * ts_float32(return_postive_value(senLength)) + res[0] * ts_float32(return_postive_value(properNouns)) + res[0] * ts_float32(return_postive_value(npVps)) + res[0] * ts_float32(return_postive_value(cScore)) + res[0] * ts_float32(return_postive_value(senPos))
        
#         totalScore = totalScore * res[0] 
        
        obj = {
            'tf_idf': res[0] * ts_float32(return_postive_value(tfIdf)),
            'sen_length': res[0] * ts_float32(return_postive_value(senLength)),
            'proper_nouns': res[0] * ts_float32(return_postive_value(properNouns)),
            'np_vps': res[0] * ts_float32(return_postive_value(npVps)),
            'c_score': res[0] * ts_float32(return_postive_value(cScore)),
            'sen_pos': res[0] * ts_float32(return_postive_value(senPos)),
#             'total_score': res[0],
            'total_score': totalScore,
            'index': r['index']
        }
#         senetnce_scores.append(res[0])
        result.append(obj)
        
#     for val in result:
#         val['total_score'] = (val['total_score'] - min(senetnce_scores)) / (max(senetnce_scores) - min(senetnce_scores))
    
    return result

# %%
def ga_ranking_model(text, D, df_map, model):
    curpath = os.path.abspath(os.curdir)
    sens = get_sentences(text)
    t = len(sens)
    coh_map = get_sen_cohesiveness(sens, model)
    result_array = []
    
    
    for i, s in enumerate(sens):
        # print(s)
        tf_idf = calculate_tf_idf_sum(s, D, df_map)
        sen_length = get_sen_length(s)
        proper_nouns = get_proper_nouns(s)
        np_vps = len(get_np_vps(s))
        c_score = coh_map[i]
        pos = get_sen_pos(i, t)
    
        rank_obj = {
            'tf_idf': tf_idf, 
            'sen_length': sen_length, 
            'proper_nouns': proper_nouns,
            'np_vps': np_vps,
            'c_score': c_score,
            'sen_pos': pos,
            'index': i
        }
        
        result_array.append(rank_obj)
        
        
    result = ga_model(result_array)

    wr = open(os.path.join(curpath, '/tmp/score.json'), "w")
    for i, r in enumerate(result):
        r["sentence"] = sens[i]
        wr.write(json.dumps(r) + "\n")
    return result, sens

# %%
def pso_model(res_array):
    min_max_map = {}    
    result = [] 
#     senetnce_scores = []
        
    for k in ['tf_idf', 'sen_length', 'proper_nouns', 'np_vps', 'c_score', 'sen_pos']:
        min_max_map.setdefault(k, {})['max'] = max([x[k] for x in res_array])
        min_max_map[k]['min'] = min([x[k] for x in res_array])
    
        
    for r in res_array:
        
        tfIdf = get_val(r['tf_idf'], min_max_map['tf_idf']['min'], min_max_map['tf_idf']['max'])
        senLength = get_val(r['sen_length'], min_max_map['sen_length']['min'], min_max_map['sen_length']['max'])
        properNouns = get_val(r['proper_nouns'], min_max_map['proper_nouns']['min'], min_max_map['proper_nouns']['max']) 
        npVps = get_val(r['np_vps'], min_max_map['np_vps']['min'], min_max_map['np_vps']['max'])
        cScore = get_val(r['c_score'], min_max_map['c_score']['min'], min_max_map['c_score']['max']) 
        senPos = ((r['sen_pos'] - min_max_map['sen_pos']['min'])/(min_max_map['sen_pos']['max'] - min_max_map['sen_pos']['min']))
        
#         options = {'c1': 0.5, 'c2': 0.3, 'w':0.9}
        options = {
            'c1': tfIdf, 
            'c2': senLength,
            'c3': properNouns,
            'c4': npVps,
            'c5': cScore,
            'c6': senPos,
            'w': 0.75
        }
        
        data  = [tfIdf, senLength, properNouns, npVps, cScore, senPos]
        
        
        optimizer = ps.single.GlobalBestPSO(n_particles=10, dimensions=6, options=options)
        
        cost, pos = optimizer.optimize(fx.sphere, iters=100)
    
#         res = cost
        
        totalScore = cost * ts_float32(return_postive_value(tfIdf)) + cost * ts_float32(return_postive_value(senLength)) + cost * ts_float32(return_postive_value(properNouns)) + cost * ts_float32(return_postive_value(npVps)) + cost * ts_float32(return_postive_value(cScore)) + cost * ts_float32(return_postive_value(senPos))
        
#         totalScore = totalScore * res[0] 
        
        obj = {
            'tf_idf': cost * ts_float32(return_postive_value(tfIdf)),
            'sen_length': cost * ts_float32(return_postive_value(senLength)),
            'proper_nouns': cost * ts_float32(return_postive_value(properNouns)),
            'np_vps': cost * ts_float32(return_postive_value(npVps)),
            'c_score': cost * ts_float32(return_postive_value(cScore)),
            'sen_pos': cost * ts_float32(return_postive_value(senPos)),
#             'total_score': cost,
            'total_score': totalScore,
            'index': r['index']
        }
#         senetnce_scores.append(res[0])
        result.append(obj)
        
#     for val in result:
#         val['total_score'] = (val['total_score'] - min(senetnce_scores)) / (max(senetnce_scores) - min(senetnce_scores))
    
    return result

# %%
def pso_ranking_model(text, D, df_map, model):
    curpath = os.path.abspath(os.curdir)
    sens = get_sentences(text)
    t = len(sens)
    coh_map = get_sen_cohesiveness(sens, model)
    result_array = []
    
    
    for i, s in enumerate(sens):
        # print(s)
        tf_idf = calculate_tf_idf_sum(s, D, df_map)
        sen_length = get_sen_length(s)
        proper_nouns = get_proper_nouns(s)
        np_vps = len(get_np_vps(s))
        c_score = coh_map[i]
        pos = get_sen_pos(i, t)
    
        rank_obj = {
            'tf_idf': tf_idf, 
            'sen_length': sen_length, 
            'proper_nouns': proper_nouns,
            'np_vps': np_vps,
            'c_score': c_score,
            'sen_pos': pos,
            'index': i
        }
        
        result_array.append(rank_obj)
        
        
    result = pso_model(result_array)

    wr = open(os.path.join(curpath, '/tmp/score.json'), "w")
    for i, r in enumerate(result):
        r["sentence"] = sens[i]
        wr.write(json.dumps(r) + "\n")
    return result, sens

# %%
def rank__V2(res_array, senetnces):
    min_max_map = {}    
    result = [] 
    sents_ranks = []
#     senetnce_scores = []
        
    for k in ['tf_idf', 'sen_length', 'proper_nouns', 'np_vps', 'c_score', 'sen_pos']:
        min_max_map.setdefault(k, {})['max'] = max([x[k] for x in res_array])
        min_max_map[k]['min'] = min([x[k] for x in res_array])
        
    for r in res_array:
        
        tfIdf = get_val(r['tf_idf'], min_max_map['tf_idf']['min'], min_max_map['tf_idf']['max'])
        senLength = get_val(r['sen_length'], min_max_map['sen_length']['min'], min_max_map['sen_length']['max'])
        properNouns = get_val(r['proper_nouns'], min_max_map['proper_nouns']['min'], min_max_map['proper_nouns']['max']) 
        npVps = get_val(r['np_vps'], min_max_map['np_vps']['min'], min_max_map['np_vps']['max'])
        cScore = get_val(r['c_score'], min_max_map['c_score']['min'], min_max_map['c_score']['max']) 
#         senPos = ((r['sen_pos'] - min_max_map['sen_pos']['min'])/(min_max_map['sen_pos']['max'] - min_max_map['sen_pos']['min']))
        senPos = r['sen_pos']
    
        sent_text = senetnces[r['index']]
        
        res = keywords_extraction(sent_text, top_p = 1, directed=False)[0][:len(sent_text.split())]
        
        resValues = res.values()
        
        resTotal = 0
        
        for val in resValues:
            resTotal += val
        
        totalScore = ts_float32(return_postive_value(tfIdf)) + ts_float32(return_postive_value(senLength)) + ts_float32(return_postive_value(properNouns)) + ts_float32(return_postive_value(npVps)) + ts_float32(return_postive_value(cScore)) + ts_float32(return_postive_value(senPos))
        
#         totalScore = totalScore * resTotal
        
        obj = {
            'tf_idf': ts_float32(return_postive_value(tfIdf)),
            'sen_length': ts_float32(return_postive_value(senLength)),
            'proper_nouns': ts_float32(return_postive_value(properNouns)),
            'np_vps': ts_float32(return_postive_value(npVps)),
            'c_score': ts_float32(return_postive_value(cScore)),
            'sen_pos': ts_float32(return_postive_value(senPos)),
#             'total_score': res[0],
            'total_score': totalScore,
            'index': r['index']
        }
#         senetnce_scores.append(res[0])
        result.append(obj)
        
#     for val in result:
#         val['total_score'] = (val['total_score'] - min(senetnce_scores)) / (max(senetnce_scores) - min(senetnce_scores))
    
    return result

# %%
def ranking_model_v2(text, D, df_map, model):
    curpath = os.path.abspath(os.curdir)
    sens = get_sentences(text)
    t = len(sens)
    coh_map = get_sen_cohesiveness(sens, model)
    result_array = []
    
    
    for i, s in enumerate(sens):
        # print(s)
        tf_idf = calculate_tf_idf_sum(s, D, df_map)
        sen_length = get_sen_length(s)
        proper_nouns = get_proper_nouns(s)
        np_vps = len(get_np_vps(s))
        c_score = coh_map[i]
        pos = get_sen_pos(i, t)
    
        rank_obj = {
            'tf_idf': tf_idf, 
            'sen_length': sen_length, 
            'proper_nouns': proper_nouns,
            'np_vps': np_vps,
            'c_score': c_score,
            'sen_pos': pos,
            'index': i
        }
        
        result_array.append(rank_obj)
        
        
    result = rank__V2(result_array, sens)

    wr = open(os.path.join(curpath, '/tmp/score.json'), "w")
    for i, r in enumerate(result):
        r["sentence"] = sens[i]
        wr.write(json.dumps(r) + "\n")
    return result, sens

# %%
def get_sen_cluster_map(sens, model, n_clusters):
    X = get_sen_vec_list(sens, model)
#     kmeans = KMeans(n_clusters=n_clusters, random_state=0).fit(X)
#     agglomerativeClustering = AgglomerativeClustering(n_clusters=None, compute_full_tree=True, distance_threshold=0.75).fit(X)
    cntr, u, u0, d, jm, p, fpc = fuzz.cluster.cmeans(np.transpose(X), n_clusters, n_clusters, error=0.005, maxiter=1000, init=None)
#     labels = agglomerativeClustering.labels_
    labels = np.argmax(u, axis=0)
#     labels = kmeans.labels_
    return labels

# %%
def get_summary_indices(cluster_score_map, sens, sum_words):
    sorted_cl_map = {}
    for key, score_map in cluster_score_map.items():
        sorted_by_value = sorted(score_map.items(), key=lambda kv: kv[1], reverse=True)
        sorted_cl_map[key] = sorted_by_value

    # Get final sentence indices.
    final_sumamry_indices = []
    x = 0
    i = 0
    print(' summary words ', sum_words)
    while (x < sum_words):
        for key, score_map in sorted_cl_map.items():

            # The below if will ensure that  current cluster has ith senetence, it can not be always the case.
            if (len(score_map) > i):

                # This condition is for breaking during loop if num words are conaition is stastified.
                if x >= sum_words:
                    break

                index = score_map[i][0]
                token_len = len(nl.word_tokenize(sens[index]))
                if token_len > 15:
                    final_sumamry_indices.append(index)
                    # TODO : don't consider those sentences whose length is less than certain threshhold.
                    x += token_len

        i += 1
    return final_sumamry_indices

# %%
def get_summary_sentences(summary_indices, sens):
    return [sens[x] for x in summary_indices]

# %%
def calculate_df():
    stop_words = stopwords.words('english') + list(punctuation)

    df_map = {}
    print("going to read corpus for calculating document frequency")
    for file_id in reuters.fileids():
        # TO Get unique occurrence of word
        words = set(tokenize(reuters.raw(file_id), stop_words))
        for w in words:
            df_map.setdefault(w, df_map.get(w, 0) + 1)
    return df_map, len(reuters.fileids())

# %%
def get_summary(input_file_path, sum_percent, model_path):
    word_to_vec_model = load_model(model_path)
    df_map, D = calculate_df()

    with open(input_file_path, 'r') as my_file:
        data = my_file.read().replace('\n', '')
        data = data.replace(".", ". ")

#     result_array, sens = get_final_sen_ranks(data, D, df_map, word_to_vec_model)
#     result_array, sens = fuzzy_ranking_model(data, D, df_map, word_to_vec_model)
#     result_array, sens = ga_ranking_model(data, D, df_map, word_to_vec_model)
    result_array, sens = pso_ranking_model(data, D, df_map, word_to_vec_model)
#     result_array, sens = ranking_model_v2(data, D, df_map, word_to_vec_model)
    cluster_labels = get_sen_cluster_map(sens, word_to_vec_model, n_clusters=2)
    total_words = sum([len(nl.word_tokenize(sen_tokens)) for sen_tokens in sens])
    sum_words = math.ceil((sum_percent / 100) * total_words)
    final_cluster_score_map = {}
    for r in result_array:
        index = r['index']
        total_score = r['total_score']
        cluster = int(cluster_labels[index])
        final_cluster_score_map.setdefault(cluster, {})[index] = total_score
    # print(final_cluster_score_map)
    summary_indices = get_summary_indices(final_cluster_score_map, sens, sum_words)
    summary_indices.sort()
    # print(summary_indices)
    return get_summary_sentences(summary_indices, sens)

# %% [markdown]
# # Final Run

# %%
# summary_percent = 20
# # input_file = r"C:\Users\Mohsin\Desktop\Semantic-text-summarizer-master\data\sample_text.txt"
# input_file = r"C:\Users\Mohsin\Desktop\Desktop\test_doc.txt"
# model_path = r"C:\Users\Mohsin\Desktop\wrd2vec\word2vec-google-news-300.gz"
# summary_sens = get_summary(input_file, summary_percent, model_path)

# %%
# print("Summary:\n")
# for s in summary_sens:
#     print(s)

# %%
# print('Orignal Text:\n', open(input_file).read()

# %%
# files_paths = [
#     r'E:\Thesis\Documments_+_Ref_Summries\DOC_1\DOC_1.txt',
#     r'E:\Thesis\Documments_+_Ref_Summries\DOC_2\DOC_2.txt',
#     r'E:\Thesis\Documments_+_Ref_Summries\DOC_3\DOC_3.txt',
#     r'E:\Thesis\Documments_+_Ref_Summries\DOC_4\DOC_4.txt',
#     r'E:\Thesis\Documments_+_Ref_Summries\DOC_5\DOC_5.txt',
#     r'E:\Thesis\Documments_+_Ref_Summries\DOC_6\DOC_6.txt',
#     r'E:\Thesis\Documments_+_Ref_Summries\DOC_7\DOC_7.txt',
#     r'E:\Thesis\Documments_+_Ref_Summries\DOC_8\DOC_8.txt',
#     r'E:\Thesis\Documments_+_Ref_Summries\DOC_9\DOC_9.txt',
#     r'E:\Thesis\Documments_+_Ref_Summries\DOC_10\DOC_10.txt'
# ]

files_paths = [
    r'E:\Thesis\Dataset_2\DOC_1\DOC_1.txt',
    r'E:\Thesis\Dataset_2\DOC_2\DOC_2.txt',
    r'E:\Thesis\Dataset_2\DOC_3\DOC_3.txt',
    r'E:\Thesis\Dataset_2\DOC_4\DOC_4.txt',
    r'E:\Thesis\Dataset_2\DOC_5\DOC_5.txt',
    r'E:\Thesis\Dataset_2\DOC_6\DOC_6.txt',
    r'E:\Thesis\Dataset_2\DOC_7\DOC_7.txt',
    r'E:\Thesis\Dataset_2\DOC_8\DOC_8.txt',
    r'E:\Thesis\Dataset_2\DOC_9\DOC_9.txt',
    r'E:\Thesis\Dataset_2\DOC_10\DOC_10.txt',
    r'E:\Thesis\Dataset_2\DOC_11\DOC_11.txt',
    r'E:\Thesis\Dataset_2\DOC_12\DOC_12.txt',
    r'E:\Thesis\Dataset_2\DOC_13\DOC_13.txt',
    r'E:\Thesis\Dataset_2\DOC_14\DOC_14.txt',
    r'E:\Thesis\Dataset_2\DOC_15\DOC_15.txt',
    r'E:\Thesis\Dataset_2\DOC_16\DOC_16.txt',
    r'E:\Thesis\Dataset_2\DOC_17\DOC_17.txt',
    r'E:\Thesis\Dataset_2\DOC_18\DOC_18.txt',
    r'E:\Thesis\Dataset_2\DOC_19\DOC_19.txt',
    r'E:\Thesis\Dataset_2\DOC_20\DOC_20.txt'
]

# %%
summary_percent = 25
model_path = r"C:\Users\Mohsin\Desktop\wrd2vec\word2vec-google-news-300.gz"
summries = []
count = 1
for file in files_paths:
    summary_sens = get_summary(file, summary_percent, model_path)
    
    obj = {
            'DOC_' + str(count) : summary_sens,
    }
    
    summries.append(obj)
    
    count += 1

    
wr = open(os.path.join(os.path.abspath(os.curdir), '/tmp/result_poposed_model.json'), "w")
for summ in summries:
    wr.write(json.dumps(summ) + "\n\n")
    
wr.close()
# Out:
# 2021-04-26 22:17:32,864 - gensim.models.utils_any2vec - INFO - loading projection weights from C:\Users\Mohsin\Desktop\wrd2vec\word2vec-google-news-300.gz
# 2021-04-26 22:18:04,929 - gensim.models.utils_any2vec - INFO - loaded (3000000, 300) matrix from C:\Users\Mohsin\Desktop\wrd2vec\word2vec-google-news-300.gz
# going to read corpus for calculating document frequency
# 2021-04-26 22:18:17,594 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.7894736842105263, 'c2': 0.7419354838709677, 'c3': 0.45454545454545453, 'c4': 1.0, 'c5': 0.900523, 'c6': 1.0, 'w': 0.75}
# pyswarms.single.global_best: 100%|█████████████████████████████████████████████████████████|100/100, best_cost=6.31e-11
# 2021-04-26 22:18:17,713 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 6.306013314071113e-11, best pos: [ 2.02920872e-06  1.56552220e-06 -4.87704900e-06 -1.31266800e-06
#   5.33630362e-06 -1.58327027e-06]
# 2021-04-26 22:18:17,723 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.31578947368421045, 'c2': 0.5483870967741935, 'c3': 0.09090909090909091, 'c4': 0.8571428571428571, 'c5': 0.33995503, 'c6': 0.9166666666666667, 'w': 0.75}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████|100/100, best_cost=9.02e-9
# 2021-04-26 22:18:17,812 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 9.021340717391852e-09, best pos: [ 1.57113332e-05  8.74391320e-06 -3.33727455e-06 -9.23817597e-05
#   8.36020474e-06  9.08948607e-06]
# 2021-04-26 22:18:17,818 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.0, 'c2': 0.0, 'c3': -0.09090909090909091, 'c4': 0.0, 'c5': 0.0, 'c6': 0.8333333333333334, 'w': 0.75}
# pyswarms.single.global_best: 100%|█████████████████████████████████████████████████████████████|100/100, best_cost=1.54
# 2021-04-26 22:18:17,899 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 1.5391911380498788, best pos: [0.15748759 0.59697106 0.20738402 0.47385793 0.27633157 0.90227809]
# 2021-04-26 22:18:17,905 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.7368421052631579, 'c2': 1.0, 'c3': 0.18181818181818182, 'c4': 0.7142857142857143, 'c5': 0.7459937, 'c6': 0.7499999999999999, 'w': 0.75}
# pyswarms.single.global_best: 100%|█████████████████████████████████████████████████████████|100/100, best_cost=7.02e-10
# 2021-04-26 22:18:17,988 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 7.018310746856851e-10, best pos: [ 6.58601171e-08  5.46330107e-06  5.60915001e-06 -1.08176024e-05
#   5.37100004e-07 -2.28737298e-05]
# 2021-04-26 22:18:17,995 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.4736842105263157, 'c2': 0.5806451612903226, 'c3': 0.36363636363636365, 'c4': 0.5714285714285714, 'c5': 0.66022956, 'c6': 0.6666666666666666, 'w': 0.75}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████|100/100, best_cost=3.41e-7
# 2021-04-26 22:18:18,078 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 3.4081241577566636e-07, best pos: [-2.80316766e-04 -2.92836267e-04  5.70404035e-06  3.62063454e-04
#   1.38973403e-04 -1.61386988e-04]
# 2021-04-26 22:18:18,084 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.36842105263157887, 'c2': 0.6451612903225806, 'c3': 0.09090909090909091, 'c4': 0.5714285714285714, 'c5': 0.4519123, 'c6': 0.5833333333333333, 'w': 0.75}
# pyswarms.single.global_best: 100%|███████████████████████████████████████████████████████████|100/100, best_cost=2.1e-8
# 2021-04-26 22:18:18,159 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 2.096593138178807e-08, best pos: [ 1.37865452e-05 -4.23467132e-05 -9.15618379e-06 -6.25762386e-05
#  -2.38804013e-05  1.20053003e-04]
# 2021-04-26 22:18:18,167 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.4736842105263157, 'c2': 0.3870967741935484, 'c3': 0.7272727272727273, 'c4': 0.5714285714285714, 'c5': 0.37471187, 'c6': 0.5, 'w': 0.75}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████|100/100, best_cost=0.00547
# 2021-04-26 22:18:18,251 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.00547274248197628, best pos: [ 0.00978464 -0.0028884  -0.07031995 -0.01541945 -0.00594458 -0.01227466]
# 2021-04-26 22:18:18,256 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 1.0, 'c2': 1.0, 'c3': 1.0, 'c4': 0.8571428571428571, 'c5': 1.0, 'c6': 0.4166666666666667, 'w': 0.75}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████|100/100, best_cost=1.17e-9
# 2021-04-26 22:18:18,338 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 1.1725187567534779e-09, best pos: [-9.99435397e-06 -1.40349777e-05 -4.76963224e-06  2.88900265e-05
#   3.49618302e-06  2.45860224e-06]
# 2021-04-26 22:18:18,344 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.5263157894736842, 'c2': 0.7741935483870968, 'c3': 0.36363636363636365, 'c4': 0.7142857142857143, 'c5': 0.6429816, 'c6': 0.33333333333333337, 'w': 0.75}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████|100/100, best_cost=1.06e-8
# 2021-04-26 22:18:18,425 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 1.0589539139929505e-08, best pos: [ 2.01045462e-06  8.91510493e-05  1.95419148e-05  3.30437116e-05
#  -9.34409175e-07 -3.41019236e-05]
# 2021-04-26 22:18:18,433 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.8421052631578947, 'c2': 0.9354838709677419, 'c3': 0.18181818181818182, 'c4': 0.7142857142857143, 'c5': 0.7189414, 'c6': 0.24999999999999997, 'w': 0.75}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████|100/100, best_cost=4.4e-10
# 2021-04-26 22:18:18,511 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 4.3990407417926163e-10, best pos: [-8.71815592e-06 -9.50295983e-06 -5.07743223e-06  6.96960142e-06
#  -2.36495766e-06 -1.39155632e-05]
# 2021-04-26 22:18:18,517 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.4736842105263157, 'c2': 0.5161290322580645, 'c3': 0.45454545454545453, 'c4': 0.42857142857142855, 'c5': 0.8493505, 'c6': 0.16666666666666666, 'w': 0.75}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████|100/100, best_cost=4.36e-9
# 2021-04-26 22:18:18,596 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 4.36061854017715e-09, best pos: [ 2.20495451e-05 -2.05828207e-06  2.25694744e-05  4.19977608e-05
#   3.32480744e-05  2.21714239e-05]
# 2021-04-26 22:18:18,601 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.4210526315789473, 'c2': 0.41935483870967744, 'c3': -0.09090909090909091, 'c4': 0.14285714285714285, 'c5': 0.33655414, 'c6': 0.08333333333333334, 'w': 0.75}
# pyswarms.single.global_best: 100%|█████████████████████████████████████████████████████████|100/100, best_cost=0.000135
# 2021-04-26 22:18:18,683 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.0001348607742535609, best pos: [0.00401697 0.00174574 0.00713298 0.00058002 0.00181042 0.00782199]
# 2021-04-26 22:18:18,688 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.4210526315789473, 'c2': 0.3548387096774194, 'c3': 0.6363636363636364, 'c4': 0.2857142857142857, 'c5': 0.58811724, 'c6': 0.0, 'w': 0.75}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████|100/100, best_cost=8.75e-5
# 2021-04-26 22:18:18,769 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 8.749062372480883e-05, best pos: [ 0.00455089 -0.00053965 -0.00620166 -0.00295506 -0.0029615   0.00324428]
# 2021-04-26 22:18:18,775 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.5789473684210525, 'c2': 0.8064516129032258, 'c3': 0.18181818181818182, 'c4': 0.8571428571428571, 'c5': 0.541236, 'c6': 0.9166666666666667, 'w': 0.75}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████|100/100, best_cost=8.01e-8
# 2021-04-26 22:18:18,855 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 8.014849512951476e-08, best pos: [-4.77708142e-05  2.61409194e-04 -6.14380683e-05 -2.75661599e-05
#  -8.05564245e-06 -7.02300163e-05]
# 2021-04-26 22:18:18,860 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.6842105263157894, 'c2': 0.8387096774193549, 'c3': 0.18181818181818182, 'c4': 0.5714285714285714, 'c5': 0.33840686, 'c6': 1.0, 'w': 0.75}
# pyswarms.single.global_best: 100%|█████████████████████████████████████████████████████████|100/100, best_cost=3.08e-11
# 2021-04-26 22:18:18,937 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 3.081750809343912e-11, best pos: [-1.68619172e-06 -1.94862434e-06  6.93888003e-07 -4.09740329e-06
#   1.84922331e-06  1.86743342e-06]
# 2021-04-26 22:18:19,517 - gensim.models.utils_any2vec - INFO - loading projection weights from C:\Users\Mohsin\Desktop\wrd2vec\word2vec-google-news-300.gz
#  summary words  104
# 2021-04-26 22:18:51,427 - gensim.models.utils_any2vec - INFO - loaded (3000000, 300) matrix from C:\Users\Mohsin\Desktop\wrd2vec\word2vec-google-news-300.gz
# going to read corpus for calculating document frequency
# 2021-04-26 22:19:04,259 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.7, 'c2': 0.75, 'c3': 0.7777777777777778, 'c4': 0.3333333333333333, 'c5': 0.79893506, 'c6': 1.0, 'w': 0.75}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████|100/100, best_cost=2.29e-9
# 2021-04-26 22:19:04,359 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 2.293162667156001e-09, best pos: [ 3.67564562e-06 -1.26443941e-06 -4.31956569e-05  6.78764232e-07
#   1.76177671e-05  1.00668902e-05]
# 2021-04-26 22:19:04,366 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 1.0, 'c2': 0.9, 'c3': 0.6666666666666666, 'c4': 1.0, 'c5': 0.88332415, 'c6': 0.6666666666666666, 'w': 0.75}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████|100/100, best_cost=4.72e-8
# 2021-04-26 22:19:04,444 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 4.723857161709795e-08, best pos: [-8.86639214e-06 -4.86277552e-05  1.92548156e-04 -5.29478581e-06
#  -2.05221227e-05  8.52720083e-05]
# 2021-04-26 22:19:04,451 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.0, 'c2': 0.0, 'c3': -0.1111111111111111, 'c4': 0.0, 'c5': 0.0, 'c6': 0.33333333333333337, 'w': 0.75}
# pyswarms.single.global_best: 100%|█████████████████████████████████████████████████████████████|100/100, best_cost=1.28
# 2021-04-26 22:19:04,523 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 1.2847852488819247, best pos: [0.3119247  0.35502182 0.36431747 0.52709986 0.68137966 0.43198151]
# 2021-04-26 22:19:04,529 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.9, 'c2': 1.0, 'c3': 0.7777777777777778, 'c4': 1.0, 'c5': 1.0, 'c6': 0.0, 'w': 0.75}
# pyswarms.single.global_best: 100%|█████████████████████████████████████████████████████████|100/100, best_cost=3.98e-10
# 2021-04-26 22:19:04,603 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 3.981766682801304e-10, best pos: [ 4.22887582e-06 -1.11789597e-05 -9.86250967e-06 -1.21087095e-05
#  -3.21520050e-06  1.04722478e-06]
# 2021-04-26 22:19:04,609 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.7, 'c2': 0.8, 'c3': 0.4444444444444444, 'c4': 0.5, 'c5': 0.845945, 'c6': 0.6666666666666666, 'w': 0.75}
# pyswarms.single.global_best: 100%|████████████████████████████████████████████████████████████|100/100, best_cost=9e-10
# 2021-04-26 22:19:04,689 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 8.997352939585795e-10, best pos: [ 5.20523544e-06 -2.47262188e-05 -2.57280394e-06 -9.12091850e-06
#   1.30567723e-05 -9.82417010e-07]
# 2021-04-26 22:19:04,695 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.7999999999999999, 'c2': 0.95, 'c3': 1.0, 'c4': 0.6666666666666666, 'c5': 0.81544286, 'c6': 1.0, 'w': 0.75}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████|100/100, best_cost=1.05e-9
# 2021-04-26 22:19:04,767 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 1.0513168800504944e-09, best pos: [ 5.84419758e-06 -2.15160182e-05  2.11668413e-06 -1.55831025e-05
#   1.17314428e-05  1.30108805e-05]
# 2021-04-26 22:19:05,463 - gensim.models.utils_any2vec - INFO - loading projection weights from C:\Users\Mohsin\Desktop\wrd2vec\word2vec-google-news-300.gz
#  summary words  43
# 2021-04-26 22:19:37,110 - gensim.models.utils_any2vec - INFO - loaded (3000000, 300) matrix from C:\Users\Mohsin\Desktop\wrd2vec\word2vec-google-news-300.gz
# going to read corpus for calculating document frequency
# 2021-04-26 22:19:50,053 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.5769230769230769, 'c2': 0.46511627906976744, 'c3': 0.14285714285714285, 'c4': 0.5, 'c5': 0.8795086, 'c6': 1.0, 'w': 0.75}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████|100/100, best_cost=3.04e-9
# 2021-04-26 22:19:50,151 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 3.0360571749838666e-09, best pos: [ 2.99053166e-05 -3.55302835e-06 -2.73012622e-05  1.29450216e-06
#  -1.77916195e-05 -3.26424390e-05]
# 2021-04-26 22:19:50,158 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.49999999999999994, 'c2': 0.5348837209302325, 'c3': 0.42857142857142855, 'c4': 0.35714285714285715, 'c5': 1.0, 'c6': 0.9655172413793104, 'w': 0.75}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████|100/100, best_cost=4.07e-8
# 2021-04-26 22:19:50,235 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 4.072251048444311e-08, best pos: [1.58580943e-04 4.91704547e-05 8.53448875e-05 7.39930744e-05
#  1.98990666e-05 1.47095998e-06]
# 2021-04-26 22:19:50,240 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.3076923076923077, 'c2': 0.3023255813953488, 'c3': 0.7142857142857143, 'c4': 0.2857142857142857, 'c5': 0.49931085, 'c6': 0.9310344827586207, 'w': 0.75}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████|100/100, best_cost=5.42e-5
# 2021-04-26 22:19:50,314 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 5.4239163370007294e-05, best pos: [ 0.00120497 -0.00011883  0.00135273  0.00583013  0.0036182  -0.00196504]
# 2021-04-26 22:19:50,320 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.038461538461538436, 'c2': 0.20930232558139536, 'c3': -0.14285714285714285, 'c4': 0.07142857142857142, 'c5': 0.43536568, 'c6': 0.896551724137931, 'w': 0.75}
# pyswarms.single.global_best: 100%|███████████████████████████████████████████████████████████|100/100, best_cost=0.0942
# 2021-04-26 22:19:50,391 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.0941577984790819, best pos: [ 0.11883897 -0.19411831  0.19620293 -0.00592957 -0.06134932  0.00766099]
# 2021-04-26 22:19:50,397 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.6153846153846153, 'c2': 0.6511627906976745, 'c3': 0.14285714285714285, 'c4': 0.5714285714285714, 'c5': 0.94398123, 'c6': 0.8620689655172413, 'w': 0.75}
# pyswarms.single.global_best: 100%|█████████████████████████████████████████████████████████|100/100, best_cost=4.63e-11
# 2021-04-26 22:19:50,472 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 4.6339064624009106e-11, best pos: [-2.98711697e-07 -1.88933763e-06 -5.65485051e-06 -2.04261325e-06
#  -2.17340699e-06  1.34422400e-06]
# 2021-04-26 22:19:50,477 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.1923076923076923, 'c2': 0.0, 'c3': -0.14285714285714285, 'c4': 0.14285714285714285, 'c5': 0.44451407, 'c6': 0.8275862068965517, 'w': 0.75}
# pyswarms.single.global_best: 100%|███████████████████████████████████████████████████████████|100/100, best_cost=0.0823
# 2021-04-26 22:19:50,555 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.08230881645850423, best pos: [ 0.17458132 -0.01530322  0.07015736 -0.08519367 -0.15905374  0.1188187 ]
# 2021-04-26 22:19:50,561 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 1.0, 'c2': 1.0, 'c3': -0.14285714285714285, 'c4': 0.5, 'c5': 0.85572946, 'c6': 0.7931034482758621, 'w': 0.75}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████|100/100, best_cost=4.34e-8
# 2021-04-26 22:19:50,639 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 4.3363336501060034e-08, best pos: [ 8.02474983e-05  2.46057106e-05  1.13298851e-04 -1.29192197e-04
#  -6.68463714e-06 -8.21358436e-05]
# 2021-04-26 22:19:50,645 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.2692307692307693, 'c2': 0.2558139534883721, 'c3': 0.0, 'c4': 0.42857142857142855, 'c5': 0.6042082, 'c6': 0.7586206896551724, 'w': 0.75}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████|100/100, best_cost=0.00102
# 2021-04-26 22:19:50,720 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.0010247493126668782, best pos: [-0.00582887 -0.00420285  0.00165133  0.02097227  0.02244323  0.00518152]
# 2021-04-26 22:19:50,725 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.6923076923076923, 'c2': 0.627906976744186, 'c3': 0.2857142857142857, 'c4': 0.5, 'c5': 0.903937, 'c6': 0.7241379310344828, 'w': 0.75}
# pyswarms.single.global_best: 100%|█████████████████████████████████████████████████████████|100/100, best_cost=3.92e-10
# 2021-04-26 22:19:50,800 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 3.9165220647444167e-10, best pos: [ 6.42257101e-06  5.74872252e-06 -6.76021021e-07 -7.72067397e-06
#   3.83615482e-07  1.60356480e-05]
# 2021-04-26 22:19:50,807 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.0769230769230769, 'c2': 0.11627906976744186, 'c3': 0.0, 'c4': 0.21428571428571427, 'c5': 0.52996755, 'c6': 0.6896551724137931, 'w': 0.75}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████|100/100, best_cost=0.00416
# 2021-04-26 22:19:50,886 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.004158165586365569, best pos: [-0.01258599  0.0622498   0.00027683 -0.00884992 -0.00511087  0.00449466]
# 2021-04-26 22:19:50,892 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.23076923076923075, 'c2': 0.37209302325581395, 'c3': 0.2857142857142857, 'c4': 0.5, 'c5': 0.15630466, 'c6': 0.6551724137931034, 'w': 0.75}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████|100/100, best_cost=7.66e-6
# 2021-04-26 22:19:50,971 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 7.658447063110343e-06, best pos: [ 1.06991458e-05 -2.73882417e-03 -3.35587878e-04  1.84210854e-04
#  -8.95606741e-05  5.09976574e-05]
# 2021-04-26 22:19:50,977 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.8846153846153846, 'c2': 0.8837209302325582, 'c3': 1.0, 'c4': 1.0, 'c5': 0.9789891, 'c6': 0.6206896551724138, 'w': 0.75}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████|100/100, best_cost=3.23e-9
# 2021-04-26 22:19:51,056 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 3.2317215409625404e-09, best pos: [ 3.44523845e-05 -2.50433091e-05 -3.74803507e-06  1.17276080e-05
#   3.50958015e-05  5.85555912e-06]
# 2021-04-26 22:19:51,060 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.15384615384615383, 'c2': 0.09302325581395349, 'c3': 0.2857142857142857, 'c4': 0.2857142857142857, 'c5': 0.3361617, 'c6': 0.5862068965517241, 'w': 0.75}
# pyswarms.single.global_best: 100%|████████████████████████████████████████████████████████████|100/100, best_cost=0.061
# 2021-04-26 22:19:51,142 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.06097699201658477, best pos: [-0.16320119 -0.11787936 -0.00547206 -0.0522673   0.00678     0.13281204]
# 2021-04-26 22:19:51,147 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.3461538461538461, 'c2': 0.5581395348837209, 'c3': 0.14285714285714285, 'c4': 0.6428571428571429, 'c5': 0.83710784, 'c6': 0.5517241379310345, 'w': 0.75}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████|100/100, best_cost=1.9e-10
# 2021-04-26 22:19:51,228 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 1.8993149453668223e-10, best pos: [-3.70344858e-06 -8.72250151e-06 -4.81201377e-06  1.15793056e-06
#  -8.47572215e-06  1.94930368e-06]
# 2021-04-26 22:19:51,233 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.0, 'c2': 0.0, 'c3': 0.0, 'c4': 0.21428571428571427, 'c5': 0.0, 'c6': 0.5172413793103449, 'w': 0.75}
# pyswarms.single.global_best: 100%|█████████████████████████████████████████████████████████████|100/100, best_cost=1.04
# 2021-04-26 22:19:51,310 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 1.0394405113373741, best pos: [0.36669472 0.46983814 0.34642324 0.53941169 0.35291025 0.38562668]
# 2021-04-26 22:19:51,315 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.3461538461538461, 'c2': 0.6046511627906976, 'c3': 0.0, 'c4': 0.2857142857142857, 'c5': 0.68871135, 'c6': 0.4827586206896552, 'w': 0.75}
# pyswarms.single.global_best: 100%|█████████████████████████████████████████████████████████|100/100, best_cost=1.85e-11
# 2021-04-26 22:19:51,394 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 1.853325009004544e-11, best pos: [ 1.74019736e-06  2.69031790e-06 -2.70899335e-06 -1.93128813e-07
#   3.07149810e-07  8.92674695e-07]
# 2021-04-26 22:19:51,399 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.6923076923076924, 'c2': 0.6511627906976745, 'c3': 0.8571428571428571, 'c4': 0.6428571428571429, 'c5': 0.9884755, 'c6': 0.4482758620689655, 'w': 0.75}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████|100/100, best_cost=1.12e-9
# 2021-04-26 22:19:51,478 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 1.1247393505291712e-09, best pos: [-9.84726014e-06  1.53206554e-05 -5.41333352e-06  4.12090657e-06
#  -2.27981215e-05 -1.50667827e-05]
# 2021-04-26 22:19:51,483 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.1923076923076923, 'c2': 0.46511627906976744, 'c3': 0.0, 'c4': 0.5, 'c5': 0.39143172, 'c6': 0.41379310344827586, 'w': 0.75}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████|100/100, best_cost=7.35e-6
# 2021-04-26 22:19:51,563 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 7.349910725607012e-06, best pos: [-0.00078836  0.00025776 -0.00134321  0.0001081  -0.00219747 -0.0001311 ]
# 2021-04-26 22:19:51,568 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.23076923076923075, 'c2': 0.20930232558139536, 'c3': 0.0, 'c4': 0.2857142857142857, 'c5': 0.37405774, 'c6': 0.3793103448275862, 'w': 0.75}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████|100/100, best_cost=0.00153
# 2021-04-26 22:19:51,646 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.0015320464060621796, best pos: [-0.00243559  0.0355583  -0.00100014  0.0137871  -0.00318922 -0.007776  ]
# 2021-04-26 22:19:51,651 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.2692307692307693, 'c2': 0.11627906976744186, 'c3': 0.0, 'c4': 0.0, 'c5': 0.51765215, 'c6': 0.3448275862068966, 'w': 0.75}
# pyswarms.single.global_best: 100%|███████████████████████████████████████████████████████████|100/100, best_cost=0.0208
# 2021-04-26 22:19:51,731 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.02079837988529865, best pos: [-0.11480748 -0.00129228 -0.0452595  -0.03272238 -0.01353599 -0.06567764]
# 2021-04-26 22:19:51,736 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.5769230769230769, 'c2': 0.4418604651162791, 'c3': 0.42857142857142855, 'c4': 0.42857142857142855, 'c5': 0.807196, 'c6': 0.3103448275862069, 'w': 0.75}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████|100/100, best_cost=2.86e-6
# 2021-04-26 22:19:51,818 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 2.8582414253481587e-06, best pos: [ 1.56969533e-03  1.16263273e-04 -3.72917808e-05  2.23711310e-04
#   3.18350832e-04 -4.77489441e-04]
# 2021-04-26 22:19:51,825 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.7307692307692306, 'c2': 0.7441860465116279, 'c3': -0.14285714285714285, 'c4': 0.7142857142857143, 'c5': 0.5947584, 'c6': 0.27586206896551724, 'w': 0.75}
# pyswarms.single.global_best: 100%|█████████████████████████████████████████████████████████|100/100, best_cost=5.56e-11
# 2021-04-26 22:19:51,901 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 5.55894920919399e-11, best pos: [ 2.08063717e-06  4.47275604e-06 -2.44766979e-06  1.04556799e-06
#   1.20671029e-06 -4.76596736e-06]
# 2021-04-26 22:19:51,908 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.3461538461538461, 'c2': 0.4418604651162791, 'c3': 0.42857142857142855, 'c4': 0.5714285714285714, 'c5': 0.69180554, 'c6': 0.2413793103448276, 'w': 0.75}
# pyswarms.single.global_best: 100%|█████████████████████████████████████████████████████████|100/100, best_cost=2.65e-10
# 2021-04-26 22:19:51,988 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 2.650820132513781e-10, best pos: [-5.82392227e-07  2.04540503e-06  1.00871427e-07 -2.09417850e-06
#  -2.14923215e-06  1.58601448e-05]
# 2021-04-26 22:19:51,994 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.23076923076923075, 'c2': 0.27906976744186046, 'c3': 0.14285714285714285, 'c4': 0.42857142857142855, 'c5': 0.4692136, 'c6': 0.20689655172413793, 'w': 0.75}
# pyswarms.single.global_best: 100%|█████████████████████████████████████████████████████████|100/100, best_cost=0.000562
# 2021-04-26 22:19:52,076 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.000562332628024061, best pos: [ 0.00306119 -0.00560362 -0.00617201 -0.00116562  0.02048601  0.0079014 ]
# 2021-04-26 22:19:52,081 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.46153846153846145, 'c2': 0.37209302325581395, 'c3': 0.5714285714285714, 'c4': 0.35714285714285715, 'c5': 0.7837297, 'c6': 0.1724137931034483, 'w': 0.75}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████|100/100, best_cost=3.02e-8
# 2021-04-26 22:19:52,164 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 3.0239510035849175e-08, best pos: [ 1.40691850e-05  3.73541177e-05 -1.42186685e-05 -9.65764656e-05
#   9.86828605e-05  9.68439298e-05]
# 2021-04-26 22:19:52,170 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.23076923076923075, 'c2': 0.18604651162790697, 'c3': 0.14285714285714285, 'c4': 0.35714285714285715, 'c5': 0.5808809, 'c6': 0.13793103448275862, 'w': 0.75}
# pyswarms.single.global_best: 100%|███████████████████████████████████████████████████████████|100/100, best_cost=0.0035
# 2021-04-26 22:19:52,250 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.0035040136658378166, best pos: [-0.00124456 -0.02959854  0.00452192  0.00628279 -0.04243829  0.02766697]
# 2021-04-26 22:19:52,255 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.3461538461538461, 'c2': 0.46511627906976744, 'c3': 0.14285714285714285, 'c4': 0.2857142857142857, 'c5': 0.86612004, 'c6': 0.10344827586206896, 'w': 0.75}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████|100/100, best_cost=3.05e-8
# 2021-04-26 22:19:52,336 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 3.0479833974143736e-08, best pos: [-1.29011962e-04  3.58299989e-05  6.29732476e-06 -2.19861437e-05
#  -3.68876016e-06  1.09614347e-04]
# 2021-04-26 22:19:52,341 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.46153846153846145, 'c2': 0.46511627906976744, 'c3': 0.14285714285714285, 'c4': 0.5, 'c5': 0.98530406, 'c6': 0.06896551724137931, 'w': 0.75}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████|100/100, best_cost=1.91e-7
# 2021-04-26 22:19:52,422 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 1.9096866252883672e-07, best pos: [ 3.44496526e-04  9.99822197e-05  1.28144289e-04 -1.07934932e-04
#  -1.84456856e-04  1.41110426e-05]
# 2021-04-26 22:19:52,427 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.46153846153846145, 'c2': 0.37209302325581395, 'c3': 0.0, 'c4': 0.5714285714285714, 'c5': 0.7962339, 'c6': 0.034482758620689655, 'w': 0.75}
# pyswarms.single.global_best:   0%|                                                            |0/100, best_cost=1.14e-6IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# 2021-04-26 22:20:25,710 - gensim.models.utils_any2vec - INFO - loaded (3000000, 300) matrix from C:\Users\Mohsin\Desktop\wrd2vec\word2vec-google-news-300.gz
# going to read corpus for calculating document frequency
# 2021-04-26 22:20:38,944 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 1.0, 'c2': 0.8333333333333334, 'c3': 0.8, 'c4': 0.6153846153846154, 'c5': 0.7705463, 'c6': 1.0, 'w': 0.75}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████|100/100, best_cost=4.23e-5
# 2021-04-26 22:20:39,039 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 4.233648057072952e-05, best pos: [ 2.94759947e-05  8.81036485e-05  1.02749358e-04 -6.50179917e-03
#  -1.95866988e-04  7.44027435e-05]
# 2021-04-26 22:20:39,046 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.3913043478260869, 'c2': 0.5714285714285714, 'c3': 0.0, 'c4': 0.38461538461538464, 'c5': 0.6926882, 'c6': 0.9411764705882354, 'w': 0.75}
# pyswarms.single.global_best: 100%|█████████████████████████████████████████████████████████|100/100, best_cost=5.35e-11
# 2021-04-26 22:20:39,125 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 5.348199171936635e-11, best pos: [ 2.73152235e-07  4.64184685e-06  3.98088517e-06 -1.09377552e-06
#   3.84123821e-06 -2.48464709e-07]
# 2021-04-26 22:20:39,130 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.5652173913043478, 'c2': 0.6666666666666666, 'c3': 0.1, 'c4': 0.6153846153846154, 'c5': 0.6764392, 'c6': 0.8823529411764706, 'w': 0.75}
# pyswarms.single.global_best: 100%|█████████████████████████████████████████████████████████|100/100, best_cost=5.36e-10
# 2021-04-26 22:20:39,208 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 5.3636930516024e-10, best pos: [ 1.59978345e-05  1.24479860e-05 -8.50294896e-06 -1.86119508e-06
#   3.22299004e-06  6.27171340e-06]
# 2021-04-26 22:20:39,213 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.6521739130434782, 'c2': 0.6666666666666666, 'c3': 0.1, 'c4': 0.5384615384615384, 'c5': 0.73005855, 'c6': 0.823529411764706, 'w': 0.75}
# pyswarms.single.global_best: 100%|█████████████████████████████████████████████████████████|100/100, best_cost=1.61e-10
# 2021-04-26 22:20:39,300 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 1.6141254310714413e-10, best pos: [ 6.10745601e-06 -2.14647248e-06 -1.97200954e-06 -7.18206335e-06
#   7.71702003e-06 -2.11681986e-06]
# 2021-04-26 22:20:39,306 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.21739130434782603, 'c2': 0.21428571428571427, 'c3': 0.0, 'c4': 0.15384615384615385, 'c5': 0.20382372, 'c6': 0.7647058823529412, 'w': 0.75}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████|100/100, best_cost=0.00847
# 2021-04-26 22:20:39,385 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.008471993565269806, best pos: [-0.01165514 -0.0327219   0.03290239  0.07823857 -0.00724692 -0.00301151]
# 2021-04-26 22:20:39,390 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.1304347826086956, 'c2': 0.09523809523809523, 'c3': 0.1, 'c4': 0.15384615384615385, 'c5': 0.28957245, 'c6': 0.7058823529411765, 'w': 0.75}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████|100/100, best_cost=0.00353
# 2021-04-26 22:20:39,472 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.003527220887219874, best pos: [ 0.03368564 -0.03315869  0.01957145  0.0036413   0.02525012 -0.01609755]
# 2021-04-26 22:20:39,477 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.9565217391304348, 'c2': 0.9047619047619048, 'c3': 0.1, 'c4': 0.6923076923076923, 'c5': 1.0, 'c6': 0.6470588235294118, 'w': 0.75}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████|100/100, best_cost=5.52e-9
# 2021-04-26 22:20:39,556 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 5.522184688644451e-09, best pos: [-3.99503319e-05 -1.78382933e-05  5.80758328e-05  1.40671170e-05
#  -4.74513646e-06 -3.84037871e-06]
# 2021-04-26 22:20:39,561 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.5217391304347826, 'c2': 0.5, 'c3': 0.2, 'c4': 0.3076923076923077, 'c5': 0.5908398, 'c6': 0.5882352941176471, 'w': 0.75}
# pyswarms.single.global_best: 100%|█████████████████████████████████████████████████████████|100/100, best_cost=2.23e-11
# 2021-04-26 22:20:39,641 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 2.2298568364985213e-11, best pos: [-2.95865139e-06  5.14983301e-07  2.12650371e-06 -1.86666797e-06
#   1.81296575e-06  1.40940780e-06]
# 2021-04-26 22:20:39,646 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.0869565217391304, 'c2': 0.0, 'c3': 0.0, 'c4': 0.07692307692307693, 'c5': 0.30039543, 'c6': 0.5294117647058825, 'w': 0.75}
# pyswarms.single.global_best: 100%|█████████████████████████████████████████████████████████████|100/100, best_cost=0.17
# 2021-04-26 22:20:39,725 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.17025247939839955, best pos: [ 0.35637022  0.17877477 -0.03462847  0.07185691  0.06565371  0.0248872 ]
# 2021-04-26 22:20:39,731 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.3913043478260869, 'c2': 0.3333333333333333, 'c3': -0.1, 'c4': 0.23076923076923078, 'c5': 0.6366727, 'c6': 0.4705882352941177, 'w': 0.75}
# pyswarms.single.global_best: 100%|███████████████████████████████████████████████████████████|100/100, best_cost=7.8e-8
# 2021-04-26 22:20:39,807 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 7.795527621349653e-08, best pos: [-8.84748521e-06 -8.36843724e-05 -8.92122581e-05 -2.31682984e-04
#   4.29207762e-05  8.59994127e-05]
# 2021-04-26 22:20:39,812 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.7826086956521738, 'c2': 0.8095238095238095, 'c3': 0.1, 'c4': 0.6923076923076923, 'c5': 0.41179654, 'c6': 0.4117647058823529, 'w': 0.75}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████|100/100, best_cost=5.35e-9
# 2021-04-26 22:20:39,891 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 5.3547447205693335e-09, best pos: [ 9.66570191e-07 -2.66255128e-06  5.83327793e-05  1.02780377e-05
#  -3.65995955e-06  4.27197235e-05]
# 2021-04-26 22:20:39,896 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.3913043478260869, 'c2': 0.2857142857142857, 'c3': 0.1, 'c4': 0.15384615384615385, 'c5': 0.61648124, 'c6': 0.3529411764705883, 'w': 0.75}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████|100/100, best_cost=7.84e-9
# 2021-04-26 22:20:39,976 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 7.843144909628153e-09, best pos: [-8.58505858e-06  1.52553060e-05 -9.54177399e-06  3.44553630e-05
#  -6.17636617e-06  7.88692103e-05]
# 2021-04-26 22:20:39,981 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 1.0, 'c2': 1.0, 'c3': 1.0, 'c4': 1.0, 'c5': 0.70886284, 'c6': 0.2941176470588235, 'w': 0.75}
# pyswarms.single.global_best: 100%|█████████████████████████████████████████████████████████|100/100, best_cost=8.57e-12
# 2021-04-26 22:20:40,059 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 8.573274172613215e-12, best pos: [-1.71232224e-06  1.15173644e-06  1.98525283e-06  2.68474107e-07
#  -5.45041389e-07  6.59744950e-08]
# 2021-04-26 22:20:40,065 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.17391304347826078, 'c2': 0.19047619047619047, 'c3': 0.0, 'c4': 0.15384615384615385, 'c5': 0.4565199, 'c6': 0.23529411764705882, 'w': 0.75}
# pyswarms.single.global_best: 100%|███████████████████████████████████████████████████████████|100/100, best_cost=0.0569
# 2021-04-26 22:20:40,146 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.056933349304424945, best pos: [-0.02078578 -0.13353005 -0.00130831  0.02510132  0.04979796 -0.18857201]
# 2021-04-26 22:20:40,152 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.3478260869565217, 'c2': 0.38095238095238093, 'c3': -0.1, 'c4': 0.07692307692307693, 'c5': 0.56667936, 'c6': 0.17647058823529413, 'w': 0.75}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████|100/100, best_cost=7.23e-6
# 2021-04-26 22:20:40,232 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 7.230093386903338e-06, best pos: [-0.00028141  0.00044127  0.00260533 -0.00016147 -0.00010987 -0.00036095]
# 2021-04-26 22:20:40,238 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.21739130434782603, 'c2': 0.30952380952380953, 'c3': -0.1, 'c4': 0.0, 'c5': 0.4577017, 'c6': 0.11764705882352942, 'w': 0.75}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████|100/100, best_cost=7.27e-7
# 2021-04-26 22:20:40,313 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 7.270540074103006e-07, best pos: [-3.77193686e-04  5.16025438e-05 -4.49952776e-05 -3.39039899e-05
#   7.60867045e-04 -4.83661964e-06]
# 2021-04-26 22:20:40,319 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.7391304347826086, 'c2': 0.7380952380952381, 'c3': 0.2, 'c4': 0.6923076923076923, 'c5': 0.6710048, 'c6': 0.05882352941176469, 'w': 0.75}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████|100/100, best_cost=9.12e-8
# 2021-04-26 22:20:40,391 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 9.121873615112423e-08, best pos: [ 8.79896480e-06 -1.18791505e-04  3.80823562e-05  2.33836436e-04
#  -1.41886986e-04 -2.77169862e-05]
# 2021-04-26 22:20:40,400 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.26086956521739124, 'c2': 0.2619047619047619, 'c3': -0.1, 'c4': 0.15384615384615385, 'c5': 0.24887319, 'c6': 0.0, 'w': 0.75}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████|100/100, best_cost=5.21e-5
# 2021-04-26 22:20:40,476 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 5.213483518100627e-05, best pos: [ 5.64203980e-05  5.38751067e-03  2.17075433e-03  7.06390639e-04
#  -4.08166387e-03 -1.11141295e-03]
# 2021-04-26 22:20:40,483 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.0, 'c2': 0.047619047619047616, 'c3': -0.1, 'c4': 0.07692307692307693, 'c5': 0.0, 'c6': 0.9411764705882354, 'w': 0.75}
# pyswarms.single.global_best: 100%|████████████████████████████████████████████████████████████|100/100, best_cost=0.416
# 2021-04-26 22:20:40,564 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.4159001252493692, best pos: [-0.00353807  0.1598822   0.25127312  0.22137734  0.52503771  0.05014565]
# 2021-04-26 22:20:40,569 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.17391304347826078, 'c2': 0.16666666666666666, 'c3': -0.1, 'c4': 0.15384615384615385, 'c5': 0.64744073, 'c6': 1.0, 'w': 0.75}
# pyswarms.single.global_best: 100%|███████████████████████████████████████████████████████████|100/100, best_cost=0.0161
# 2021-04-26 22:20:40,643 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.016127227510386914, best pos: [ 0.0589913  -0.01667998  0.05991502  0.07170324 -0.01535922  0.05832634]
#  summary words  120
# 2021-04-26 22:20:41,364 - gensim.models.utils_any2vec - INFO - loading projection weights from C:\Users\Mohsin\Desktop\wrd2vec\word2vec-google-news-300.gz
# 2021-04-26 22:21:13,310 - gensim.models.utils_any2vec - INFO - loaded (3000000, 300) matrix from C:\Users\Mohsin\Desktop\wrd2vec\word2vec-google-news-300.gz
# going to read corpus for calculating document frequency
# 2021-04-26 22:21:26,346 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.7142857142857142, 'c2': 0.6, 'c3': 0.5714285714285714, 'c4': 0.5833333333333334, 'c5': 0.9951679901130999, 'c6': 1.0, 'w': 0.75}
# pyswarms.single.global_best: 100%|█████████████████████████████████████████████████████████|100/100, best_cost=9.62e-10
# 2021-04-26 22:21:26,453 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 9.618942440624254e-10, best pos: [-2.71783989e-05  2.66102281e-06  6.53454698e-06 -9.84189898e-06
#  -4.99644312e-06  7.18471375e-06]
# 2021-04-26 22:21:26,465 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.6785714285714285, 'c2': 0.6, 'c3': 0.0, 'c4': 0.6666666666666666, 'c5': 0.8620125606683557, 'c6': 0.96875, 'w': 0.75}
# pyswarms.single.global_best: 100%|█████████████████████████████████████████████████████████|100/100, best_cost=6.18e-10
# 2021-04-26 22:21:26,544 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 6.178073857630425e-10, best pos: [ 2.69601253e-06  4.85174128e-07 -1.78070014e-05  3.70118146e-08
#   1.69235256e-05  2.60904637e-06]
# 2021-04-26 22:21:26,550 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.8928571428571428, 'c2': 1.0, 'c3': 1.0, 'c4': 1.0, 'c5': 0.7999180303481569, 'c6': 0.9375, 'w': 0.75}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████|100/100, best_cost=1.82e-9
# 2021-04-26 22:21:26,628 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 1.8214379280749695e-09, best pos: [ 7.85888459e-06  2.26209524e-05  2.38875481e-05 -7.69128988e-06
#  -3.35094308e-06 -2.46367340e-05]
# 2021-04-26 22:21:26,634 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.10714285714285711, 'c2': 0.1, 'c3': -0.14285714285714285, 'c4': 0.08333333333333333, 'c5': 0.5707677141127652, 'c6': 0.90625, 'w': 0.75}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████|100/100, best_cost=0.00721
# 2021-04-26 22:21:26,708 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.007206685951482761, best pos: [-0.00744753 -0.06845811 -0.00482861  0.03878911  0.00309544 -0.0304502 ]
# 2021-04-26 22:21:26,713 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.35714285714285704, 'c2': 0.25, 'c3': 0.5714285714285714, 'c4': 0.16666666666666666, 'c5': 0.8470241356099429, 'c6': 0.875, 'w': 0.75}
# pyswarms.single.global_best: 100%|█████████████████████████████████████████████████████████|100/100, best_cost=0.000935
# 2021-04-26 22:21:26,788 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.000934769395945646, best pos: [-0.01217681  0.01521071 -0.00682898 -0.00263489 -0.01298178  0.01824897]
# 2021-04-26 22:21:26,793 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.0357142857142857, 'c2': 0.06666666666666667, 'c3': -0.14285714285714285, 'c4': 0.08333333333333333, 'c5': 0.20052171264597965, 'c6': 0.8437500000000001, 'w': 0.75}
# pyswarms.single.global_best: 100%|████████████████████████████████████████████████████████████|100/100, best_cost=0.628
# 2021-04-26 22:21:26,869 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.6284478207551761, best pos: [0.09173131 0.47092129 0.30204634 0.15916707 0.38198301 0.36849581]
# 2021-04-26 22:21:26,875 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.10714285714285711, 'c2': 0.16666666666666666, 'c3': -0.14285714285714285, 'c4': 0.16666666666666666, 'c5': 0.35054468109228704, 'c6': 0.8125, 'w': 0.75}
# pyswarms.single.global_best: 100%|███████████████████████████████████████████████████████████|100/100, best_cost=0.0239
# 2021-04-26 22:21:26,959 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.023945339178494496, best pos: [-0.01422848 -0.0442249  -0.12126658  0.03493937 -0.06991751  0.03118088]
# 2021-04-26 22:21:26,965 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.2857142857142856, 'c2': 0.2833333333333333, 'c3': 0.0, 'c4': 0.4166666666666667, 'c5': 0.7732928476101874, 'c6': 0.78125, 'w': 0.75}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████|100/100, best_cost=6.45e-8
# 2021-04-26 22:21:27,041 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 6.447020466454791e-08, best pos: [-7.43679877e-06 -1.01078575e-05  1.61637683e-04  2.59631280e-05
#   6.24680625e-05 -1.83329339e-04]
# 2021-04-26 22:21:27,046 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.32142857142857134, 'c2': 0.26666666666666666, 'c3': 0.5714285714285714, 'c4': 0.5833333333333334, 'c5': 0.7275276802842733, 'c6': 0.75, 'w': 0.75}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████|100/100, best_cost=0.00806
# 2021-04-26 22:21:27,123 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.008058205745873683, best pos: [-0.01795564 -0.02789527  0.05121294 -0.06330815 -0.01807759 -0.00041016]
# 2021-04-26 22:21:27,130 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.1428571428571428, 'c2': 0.16666666666666666, 'c3': -0.14285714285714285, 'c4': 0.0, 'c5': 0.6170619887111772, 'c6': 0.71875, 'w': 0.75}
# pyswarms.single.global_best: 100%|███████████████████████████████████████████████████████████|100/100, best_cost=0.0279
# 2021-04-26 22:21:27,207 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.02789559825789083, best pos: [-0.13705254 -0.02836304 -0.05913946 -0.00110415 -0.04050652  0.05628733]
# 2021-04-26 22:21:27,213 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.2499999999999999, 'c2': 0.25, 'c3': 0.0, 'c4': 0.4166666666666667, 'c5': 0.6577952533465724, 'c6': 0.6875, 'w': 0.75}
# ...
# pyswarms.single.global_best: 100%|███████████████████████████████████████████████████████████|100/100, best_cost=1.2e-7
# 2021-04-26 22:31:39,034 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 1.203564366125761e-07, best pos: [ 8.66342651e-06  1.81231229e-05 -5.01551588e-05  1.16001550e-04
#   1.03541577e-04 -3.05385291e-04]
# 2021-04-26 22:31:39,040 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.4499999999999999, 'c2': 0.4878048780487805, 'c3': 0.0, 'c4': 0.5, 'c5': 0.8203615, 'c6': 0.2692307692307692, 'w': 0.75}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████|100/100, best_cost=9.66e-8
# 2021-04-26 22:31:39,127 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 9.664347381605176e-08, best pos: [-1.50845411e-05  1.20898510e-04  3.33987854e-05 -1.27468858e-04
#   1.20236748e-04 -2.23559425e-04]
# 2021-04-26 22:31:39,133 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.3, 'c2': 0.3170731707317073, 'c3': -0.125, 'c4': 0.1, 'c5': 0.32213956, 'c6': 0.23076923076923075, 'w': 0.75}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████|100/100, best_cost=2.54e-6
# 2021-04-26 22:31:39,221 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 2.5403141807900923e-06, best pos: [ 0.00045002  0.00010152 -0.0010035   0.00102741  0.00022366 -0.00046355]
# 2021-04-26 22:31:39,228 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.6, 'c2': 0.4878048780487805, 'c3': 0.625, 'c4': 0.5, 'c5': 0.6351274, 'c6': 0.19230769230769232, 'w': 0.75}
# pyswarms.single.global_best: 100%|█████████████████████████████████████████████████████████|100/100, best_cost=2.45e-12
# 2021-04-26 22:31:39,319 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 2.4501669718789455e-12, best pos: [ 1.24918696e-06 -3.23337824e-07 -1.58192412e-07 -6.54477163e-07
#  -4.52692132e-07 -3.56168768e-07]
# 2021-04-26 22:31:39,327 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.49999999999999994, 'c2': 0.6585365853658537, 'c3': -0.125, 'c4': 0.6, 'c5': 0.5962905, 'c6': 0.15384615384615385, 'w': 0.75}
# pyswarms.single.global_best: 100%|█████████████████████████████████████████████████████████|100/100, best_cost=2.82e-10
# 2021-04-26 22:31:39,410 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 2.8233556099335623e-10, best pos: [-8.40988038e-06 -7.01260472e-06  5.97903343e-07 -1.15397174e-05
#  -5.31106633e-06  8.38365368e-07]
# 2021-04-26 22:31:39,417 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.3, 'c2': 0.4146341463414634, 'c3': -0.125, 'c4': 0.2, 'c5': 0.48170057, 'c6': 0.11538461538461539, 'w': 0.75}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████|100/100, best_cost=0.00192
# 2021-04-26 22:31:39,501 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.0019244174072707942, best pos: [ 0.00138496  0.03453928 -0.00075137  0.00344019  0.0259389   0.00665668]
# 2021-04-26 22:31:39,508 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.35000000000000003, 'c2': 0.3902439024390244, 'c3': 0.125, 'c4': 0.2, 'c5': 0.540725, 'c6': 0.07692307692307693, 'w': 0.75}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████|100/100, best_cost=1.89e-7
# 2021-04-26 22:31:39,590 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 1.88919999315621e-07, best pos: [-3.73912787e-05  4.30072701e-04  1.44232517e-05 -1.61729198e-06
#  -1.74941741e-05  4.51959197e-05]
# 2021-04-26 22:31:39,597 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.25, 'c2': 0.4634146341463415, 'c3': 0.0, 'c4': 0.2, 'c5': 0.29592937, 'c6': 0.038461538461538464, 'w': 0.75}
# pyswarms.single.global_best: 100%|█████████████████████████████████████████████████████████|100/100, best_cost=0.000271
# 2021-04-26 22:31:39,678 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.0002713775364909306, best pos: [-1.38739682e-02 -6.76149637e-03 -3.11714961e-03 -2.06813430e-03
#   4.37935395e-03 -1.29980141e-05]
# 2021-04-26 22:31:39,686 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.6, 'c2': 0.4878048780487805, 'c3': 0.0, 'c4': 0.8, 'c5': 0.8400368, 'c6': 0.0, 'w': 0.75}
# pyswarms.single.global_best: 100%|█████████████████████████████████████████████████████████|100/100, best_cost=4.24e-10
# 2021-04-26 22:31:39,769 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 4.241755750459017e-10, best pos: [ 4.22728733e-07 -3.72810120e-06 -4.33597711e-06 -3.66205449e-06
#  -1.90962206e-06 -1.93452873e-05]
# 2021-04-26 22:31:39,775 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 1.0, 'c2': 0.9512195121951219, 'c3': 1.0, 'c4': 0.7, 'c5': 0.88121295, 'c6': 0.9615384615384615, 'w': 0.75}
# pyswarms.single.global_best: 100%|█████████████████████████████████████████████████████████|100/100, best_cost=2.07e-10
# 2021-04-26 22:31:39,861 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 2.0673519426586382e-10, best pos: [-1.55420657e-06  9.31731234e-06  5.24410151e-06  6.13664652e-06
#   3.45020829e-06 -6.35958792e-06]
# 2021-04-26 22:31:39,866 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.09999999999999998, 'c2': 0.4146341463414634, 'c3': -0.125, 'c4': 0.4, 'c5': 0.16289446, 'c6': 1.0, 'w': 0.75}
# pyswarms.single.global_best:   0%|                                                            |0/100, best_cost=1.32e-6IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# 2021-04-26 22:32:12,537 - gensim.models.utils_any2vec - INFO - loaded (3000000, 300) matrix from C:\Users\Mohsin\Desktop\wrd2vec\word2vec-google-news-300.gz
# going to read corpus for calculating document frequency
# 2021-04-26 22:32:25,219 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 1.0, 'c2': 1.0, 'c3': 0.6, 'c4': 1.0, 'c5': 1.0, 'c6': 1.0, 'w': 0.75}
# pyswarms.single.global_best: 100%|█████████████████████████████████████████████████████████|100/100, best_cost=7.15e-10
# 2021-04-26 22:32:25,324 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 7.14548731656495e-10, best pos: [ 1.12640954e-05 -2.11598662e-05  1.47008914e-07 -1.04606848e-05
#  -1.23415032e-06  5.38129030e-06]
# 2021-04-26 22:32:25,330 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.5833333333333333, 'c2': 0.9565217391304348, 'c3': 0.4, 'c4': 1.0, 'c5': 0.6331804, 'c6': 0.6666666666666666, 'w': 0.75}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████|100/100, best_cost=2.17e-9
# 2021-04-26 22:32:25,408 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 2.1743381560292223e-09, best pos: [ 1.49842431e-05 -3.57948393e-05 -2.46695502e-05 -4.73865406e-06
#  -5.96479068e-06  1.38557377e-06]
# 2021-04-26 22:32:25,413 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.0, 'c2': 0.2608695652173913, 'c3': 0.2, 'c4': 0.0, 'c5': 0.37161568, 'c6': 0.33333333333333337, 'w': 0.75}
# pyswarms.single.global_best: 100%|███████████████████████████████████████████████████████████|100/100, best_cost=0.0135
# 2021-04-26 22:32:25,490 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.013497994167919698, best pos: [ 0.06183882  0.04101672 -0.02444143 -0.0169412   0.07377324 -0.04080078]
# 2021-04-26 22:32:25,496 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.0, 'c2': 0.0, 'c3': 0.0, 'c4': 0.25, 'c5': 0.67831063, 'c6': 0.0, 'w': 0.75}
# pyswarms.single.global_best: 100%|████████████████████████████████████████████████████████████|100/100, best_cost=0.795
# 2021-04-26 22:32:25,567 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.7954024073951571, best pos: [0.05912888 0.32575156 0.19489917 0.77430679 0.21899306 0.01724691]
# 2021-04-26 22:32:25,573 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.75, 'c2': 0.782608695652174, 'c3': 1.0, 'c4': 0.25, 'c5': 0.68700564, 'c6': 0.6666666666666666, 'w': 0.75}
# pyswarms.single.global_best: 100%|█████████████████████████████████████████████████████████|100/100, best_cost=9.53e-10
# 2021-04-26 22:32:25,650 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 9.526119159270968e-10, best pos: [-1.33403530e-05  7.63195635e-06 -1.37524580e-05 -4.27017396e-06
#   6.26760560e-06  2.16737808e-05]
# 2021-04-26 22:32:25,656 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.08333333333333334, 'c2': 0.21739130434782608, 'c3': -0.2, 'c4': 0.25, 'c5': 0.0, 'c6': 1.0, 'w': 0.75}
# pyswarms.single.global_best: 100%|███████████████████████████████████████████████████████████|100/100, best_cost=0.0868
# 2021-04-26 22:32:25,732 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.08678233534263625, best pos: [-0.14063186  0.19750546  0.02288156 -0.15284045 -0.06043382  0.02146142]
# 2021-04-26 22:32:26,291 - gensim.models.utils_any2vec - INFO - loading projection weights from C:\Users\Mohsin\Desktop\wrd2vec\word2vec-google-news-300.gz
#  summary words  34
# 2021-04-26 22:32:58,266 - gensim.models.utils_any2vec - INFO - loaded (3000000, 300) matrix from C:\Users\Mohsin\Desktop\wrd2vec\word2vec-google-news-300.gz
# going to read corpus for calculating document frequency
# 2021-04-26 22:33:10,973 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.6206896551724137, 'c2': 0.5576923076923077, 'c3': 1.0, 'c4': 0.6153846153846154, 'c5': 0.75377584, 'c6': 1.0, 'w': 0.75}
# pyswarms.single.global_best: 100%|█████████████████████████████████████████████████████████|100/100, best_cost=1.76e-10
# 2021-04-26 22:33:11,091 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 1.7554013879776753e-10, best pos: [-2.89676286e-06  3.89642421e-06  5.69639065e-07  3.82850016e-06
#  -1.13860762e-05 -2.70963980e-06]
# 2021-04-26 22:33:11,097 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.3448275862068965, 'c2': 0.25, 'c3': 1.0, 'c4': 0.23076923076923078, 'c5': 0.73926455, 'c6': 0.8750000000000001, 'w': 0.75}
# pyswarms.single.global_best: 100%|███████████████████████████████████████████████████████████|100/100, best_cost=0.0038
# 2021-04-26 22:33:11,176 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.0037972342101317705, best pos: [-0.01591909 -0.03168501  0.0117867   0.00163785  0.0484128  -0.00738025]
# 2021-04-26 22:33:11,181 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.44827586206896547, 'c2': 0.5576923076923077, 'c3': 0.0, 'c4': 0.38461538461538464, 'c5': 0.7274955, 'c6': 0.7499999999999999, 'w': 0.75}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████|100/100, best_cost=3.18e-8
# 2021-04-26 22:33:11,260 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 3.1753120402596525e-08, best pos: [-8.72595684e-06 -7.58899992e-05 -2.31344027e-05  6.29336154e-06
#  -1.72956164e-05 -1.58252143e-04]
# 2021-04-26 22:33:11,266 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 1.0, 'c2': 1.0, 'c3': 1.0, 'c4': 1.0, 'c5': 1.0, 'c6': 0.625, 'w': 0.75}
# pyswarms.single.global_best: 100%|█████████████████████████████████████████████████████████|100/100, best_cost=1.61e-10
# 2021-04-26 22:33:11,345 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 1.6095623454825602e-10, best pos: [ 3.15582242e-06  9.86698524e-06  5.87078796e-06 -3.51494650e-06
#  -2.22412736e-06 -1.36816627e-06]
# 2021-04-26 22:33:11,350 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.31034482758620685, 'c2': 0.4230769230769231, 'c3': 0.6, 'c4': 0.5384615384615384, 'c5': 0.55767995, 'c6': 0.49999999999999994, 'w': 0.75}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████|100/100, best_cost=2.37e-8
# 2021-04-26 22:33:11,428 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 2.374804426684504e-08, best pos: [-2.49917099e-05 -7.82715776e-05 -2.05814541e-05  1.23567814e-04
#   2.07366968e-05 -2.95703808e-05]
# 2021-04-26 22:33:11,434 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.24137931034482754, 'c2': 0.17307692307692307, 'c3': 0.8, 'c4': 0.38461538461538464, 'c5': 0.7538035, 'c6': 0.37499999999999994, 'w': 0.75}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████|100/100, best_cost=0.00502
# 2021-04-26 22:33:11,510 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.00502149482262688, best pos: [ 0.01130122 -0.02366134 -0.01061473  0.00950086  0.05941377  0.02451496]
# 2021-04-26 22:33:11,515 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.31034482758620685, 'c2': 0.3269230769230769, 'c3': 0.0, 'c4': 0.38461538461538464, 'c5': 0.5803942, 'c6': 0.25, 'w': 0.75}
# pyswarms.single.global_best: 100%|█████████████████████████████████████████████████████████|100/100, best_cost=0.000351
# 2021-04-26 22:33:11,595 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.00035071978512947173, best pos: [-0.01257962 -0.0020599  -0.00488594 -0.01280529  0.00060449 -0.00012816]
# 2021-04-26 22:33:11,600 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.06896551724137928, 'c2': 0.09615384615384616, 'c3': -0.2, 'c4': 0.15384615384615385, 'c5': 0.31933808, 'c6': 0.12499999999999996, 'w': 0.75}
# pyswarms.single.global_best: 100%|█████████████████████████████████████████████████████████|100/100, best_cost=0.000706
# 2021-04-26 22:33:11,680 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.0007055502892298183, best pos: [ 0.01070111  0.02034972 -0.00347481  0.00810091  0.00370683  0.00924584]
# 2021-04-26 22:33:11,686 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.5862068965517241, 'c2': 0.7307692307692307, 'c3': 1.0, 'c4': 0.5384615384615384, 'c5': 0.69118595, 'c6': 0.0, 'w': 0.75}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████|100/100, best_cost=2.99e-8
# 2021-04-26 22:33:11,766 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 2.9913488823933864e-08, best pos: [ 3.43311557e-05  1.15380264e-06 -1.21398682e-04 -1.98579104e-05
#  -1.15853224e-04  1.34008647e-05]
# 2021-04-26 22:33:11,772 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.24137931034482754, 'c2': 0.2692307692307692, 'c3': 0.0, 'c4': 0.15384615384615385, 'c5': 0.74205154, 'c6': 0.8750000000000001, 'w': 0.75}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████|100/100, best_cost=0.00362
# 2021-04-26 22:33:11,850 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.0036179718069301236, best pos: [-0.00569062 -0.00845325  0.02456598  0.00348524 -0.0523472  -0.01258044]
# 2021-04-26 22:33:11,855 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.0, 'c2': 0.0, 'c3': -0.2, 'c4': 0.0, 'c5': 0.0, 'c6': 1.0, 'w': 0.75}
# pyswarms.single.global_best: 100%|████████████████████████████████████████████████████████████|100/100, best_cost=0.638
# 2021-04-26 22:33:11,933 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.6383373398749043, best pos: [0.54259476 0.44933497 0.30776598 0.0493755  0.19818356 0.0747783 ]
#  summary words  71
